# %% [markdown]
# ### <font color=pink>**TASK 4** </fonts>

# %%
Analyze traffic accident data to identify patterns related to road conditions weather , and time of day. Visualize accident hotspots and
contributing factors.

# %% [markdown]
# ### <font color=pink>**TRAFFIC ACCIDENT DATA ANALYSIS** </fonts>

# %% [markdown]
# ##### <font color=Lightblue>**Import Necessary Libraries** </fonts>

# %%
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### <font color=Lightblue>**Load the dataset** </fonts>

# %%
data=pd.read_csv("C:\\Users\\hp\\OneDrive\\Documents\\US_Accidents_March23.csv")
data
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# ...

# %% [markdown]
# ##### <font color=Lightblue>**Structure of dataset** </fonts>

# %%
#Display first five rows
data.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
#Display last five rows
data.tail()
# Out:
#                 ID   Source  Severity           Start_Time  \
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat  Start_Lng   End_Lat    End_Lng  \
# 7728389  2019-08-23 18:32:01   34.00248 -117.37936  33.99888 -117.37094
# 7728390  2019-08-23 19:38:23   32.76696 -117.14806  32.76555 -117.15363
# 7728391  2019-08-23 19:28:49   33.77545 -117.84779  33.77740 -117.85727
# 7728392  2019-08-23 19:29:42   33.99246 -118.40302  33.98311 -118.39565
# 7728393  2019-08-23 19:21:31   34.13393 -117.23092  34.13736 -117.23934
#
#          Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 7728389         0.543  ...      False   False  False           False
# ...

# %%
#Shape of the dataset
data.shape
# Out:
# (7728394, 46)

# %%
#Data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
#Statistical Analysis of dataset
data.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %% [markdown]
# ##### <font color=Lightblue>**Checking Missing Values** </fonts>

# %%
data.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %% [markdown]
# ##### <font color=Lightblue>**Check Duplicates** </fonts>

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### <font color=Lightblue>**Extract Time Based Features** </fonts>

# %%
data['Start_Time'] = pd.to_datetime(data['Start_Time'], errors='coerce', infer_datetime_format=True)
data['End_Time'] = pd.to_datetime(data['End_Time'], errors='coerce', infer_datetime_format=True)

# %%
# Extract hour of the day
data['Hour'] = data['Start_Time'].dt.hour

# Count accidents per hour
hourly_counts = data['Hour'].value_counts().sort_index()

# Plot
plt.figure(figsize=(12,6))
sns.barplot(x=hourly_counts.index, y=hourly_counts.values)
plt.title("Accidents Per Hour")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Accidents")
plt.show()

# %% [markdown]
# ###### <font color=Lightblue>**Accidents By Weather Conditions** </fonts>

# %%
#Accidents by weather Condition
weather_counts = data['Weather_Condition'].value_counts().nlargest(10)

plt.figure(figsize=(12,6))
sns.barplot(x=weather_counts.values, y=weather_counts.index)
plt.title('Top 10 Weather Conditions During Accidents')
plt.xlabel('Number of Accidents')
plt.ylabel('Weather Condition')
plt.show()

# %% [markdown]
# ###### <font color=Lightblue>**Accident severity by road Condition** </fonts>

# %%
road_features = ['Junction', 'Traffic_Signal', 'Crossing', 'Stop']
for feature in road_features:
    sns.barplot(x=feature, y='Severity', data=data)
    plt.title(f'Accident Severity by {feature}')
    plt.show()

# %% [markdown]
# ###### <font color=Lightblue>**Visualize Accident Hotspots** </fonts>

# %%
#Use Start_Lat and Start_lng to Visualize Hotspots
plt.figure(figsize=(10,8))
plt.scatter(data['Start_Lng'], data['Start_Lat'], s=0.05, alpha=0.2)
plt.title('Accident Locations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ###### <font color=Lightblue>**Identify Key Contributing Factors** </fonts>

# %%
#Correlation With severity
data[['Severity', 'Visibility(mi)', 'Wind_Speed(mph)', 'Humidity(%)', 'Temperature(F)']].corr()
# Out:
#                  Severity  Visibility(mi)  Wind_Speed(mph)  Humidity(%)  \
# Severity         1.000000       -0.003473         0.040214     0.022293
# Visibility(mi)  -0.003473        1.000000         0.014650    -0.384261
# Wind_Speed(mph)  0.040214        0.014650         1.000000    -0.172403
# Humidity(%)      0.022293       -0.384261        -0.172403     1.000000
# Temperature(F)  -0.020327        0.217173         0.033750    -0.330939
#
#                  Temperature(F)
# Severity              -0.020327
# Visibility(mi)         0.217173
# Wind_Speed(mph)        0.033750
# Humidity(%)           -0.330939
# Temperature(F)         1.000000
